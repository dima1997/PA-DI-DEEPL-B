# %% [markdown]
# # Graded lab session 5 | Deep classification on Fashion-MNIST using pytorch
#
# pierre-henri.conze@imt-atlantique.fr
#
# francois.rousseau@imt-atlantique.fr
#
#
# ---

# %% [markdown]
# #### **Student name** = Franco Martin DI MARIA, Timothé BULLIARD

# %% [markdown]
# ### Objective of this lab session: perform classification on Fashion-MNIST using multi-layer perceptron, convolutional neural networks and transfer learning to obtain the best classification results as possible.

# %% [markdown]
# #### Challenge: the first 3 students in terms of overall test accuracy results (whatever the methodology used) will obtain bonus points!

# %% [markdown]
# ### Table of Contents
#
# * [Data management](#section_1)
#     * [Question 1.1](#question_1_1)
#     * [Question 1.2](#question_1_2)
#     * [Question 1.3](#question_1_3)
#     * [Question 1.4](#question_1_4)
# * [Multi-Layer Perceptron](#section_2)
#     * [Question 2.1](#question_2_1)
#     * [Question 2.2](#question_2_2)
#     * [Question 2.3](#question_2_3)
#     * [Question 2.4](#question_2_4)
#     * [Question 2.5](#question_2_5)
# * [Convolutional neural network](#section_3)
#     * [Question 3.1](#question_3_1)
#     * [Question 3.2](#question_3_2)
#     * [Question 3.3](#question_3_3)
#     * [Question 3.4](#question_3_4)
#     * [Question 3.5](#question_3_5)
#     * [Question 3.6](#question_3_6)
#     * [Question 3.7](#question_3_7)
# * [Transfer learning from ImageNet](#section_4)
#     * [Question 4.1](#question_4_1)
#     * [Question 4.2](#question_4_2)
#     * [Question 4.3](#question_4_3)
#     * [Question 4.4](#question_4_4)
#     * [Question 4.5](#question_4_5)
# * [Challenge](#section_5)
#     * [Question 5.1](#question_5_1)

# %% [markdown]
# ## 1- Data management <a class="anchor" id="section_1"></a>
#
# Start with these lines of code to automatically download the Fashion-MNIST dataset.

# %%
from torchvision import datasets
import torchvision.transforms as transforms

transform = transforms.ToTensor()

train_data = datasets.FashionMNIST(root = 'data', train = True, download = True, transform = transform)
test_data = datasets.FashionMNIST(root = 'data', train = False, download = True, transform = transform)

# %% [markdown]
# #### **Question 1.1** - Fashion-MNIST is a dataset consisting of a training set of A examples and a test set of B examples. Each example is a CxC grayscale image, associated with a label from D classes. What are the values for A, B, C and D? <a class="anchor" id="question_1_1"></a>

# %%
print(f"A : {train_data.data.shape[0]}")
print(f"B : {test_data.data.shape[0]}")
print(f"C : {train_data.data.shape[1:]}")
print(f"D : {len(train_data.classes)}")
# Out:
# A : 60000
# B : 10000
# C : torch.Size([28, 28])
# D : 10

# %% [markdown]
# As indicated below, each Fashion-MNIST sample is assigned to one of the following classes: 0: T-shirt/top, 1: Trouser, 2: Pullover, 3: Dress, 4: Coat, 5: Sandal, 6: Shirt, 7: Sneaker, 8: Bag, 9: Ankle boot.

# %%
class_names = train_data.classes
print(class_names)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# #### **Question 1.2** - Complete the following cell to create data loaders ([documentation](https://pytorch.org/docs/stable/data.html)) for training, validation and test sets. <a class="anchor" id="question_1_2"></a>

# %%
import torch
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np

batch_size = 20
valid_size = 0.2

def create_data_loaders(batch_size, valid_size, train_data, test_data): # FUNCTION TO BE COMPLETED
    num_train = len(train_data)
    
    indices = list(range(num_train))
    np.random.shuffle(indices)
    split = int(np.floor(valid_size * num_train))
    train_index, valid_index = indices[split:], indices[:split]
    
    train_sampler = SubsetRandomSampler(train_index)
    valid_sampler = SubsetRandomSampler(valid_index)
    
    train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, sampler = train_sampler)
    valid_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, sampler = valid_sampler)
    test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size)

    return train_loader, valid_loader, test_loader

# %%
train_loader, valid_loader, test_loader = create_data_loaders(batch_size, valid_size, train_data, test_data) # TO DO

# %% [markdown]
# #### **Question 1.3** - Visualize some images from the training set with corresponding ground truth labels. <a class="anchor" id="question_1_3"></a>

# %%
# CELL TO BE COMPLETED
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

data_iter = iter(train_loader) 
images, labels = next(data_iter) # obtain one batch from the train set
images = images.numpy()
# plot images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray') # .npsqueeze removes single-dimensional entries from the shape of an array
    ax.set_title(str(class_names[labels[idx].item()])) # .item() gets the value contained in a Tensor

# %% [markdown]
# #### **Question 1.4** - View one of these images with more details by superimposing the greyscale intensity values directly on it. <a class="anchor" id="question_1_4"></a>

# %%
# CELL TO BE COMPLETED
img = np.squeeze(images[1])
fig = plt.figure(figsize = (10,10)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y],1) if img[x][y] !=0 else 0
        ax.annotate(str(val), xy=(y,x), horizontalalignment='center', verticalalignment='center', color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ## 2- Multi-Layer Perceptron (MLP) <a class="anchor" id="section_2"></a>

# %% [markdown]
# First, let us use a multi-layer perceptron (MLP) to automatically classify Fashion-MNIST images.

# %% [markdown]
# #### **Question 2.1** - Define a MPL architecture with (at least) 2 fully-connected as well as dropout layers. <a class="anchor" id="question_2_1"></a>

# %%
import torch.nn as nn
import torch.nn.functional as F

class MLP(nn.Module):
    def __init__(self): # FUNCTION TO BE COMPLETED
        super(MLP,self).__init__()
        # Common ReLU
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.2)
        
        # Hidden layer 1
        self.fc1 = nn.Linear(28*28, 512)
        # ReLU 1
        # Dropout 1
        
        # Hidden layer 2
        self.fc2 = nn.Linear(512, 512)
        # ReLU 2
        # Dropout 2
        
        # Output layer
        self.fc3 = nn.Linear(512, 10)

    def forward(self,x): # FUNCTION TO BE COMPLETED
        x = x.view(-1,28*28) # flatten input image
        
        # Hidden Layer 1
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)

        # Hidden Layer 2
        x = self.fc2(x)
        x = self.relu(x)
        x = self.dropout(x)

        # Output Layer 1
        y_pred = self.fc3(x)

        return x

# %% [markdown]
# #### **Question 2.2** - Train the pre-defined MPL network with cross entropy as loss function and stochastic gradient descent as optimization algorithm. <a class="anchor" id="question_2_2"></a>

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device '+str(device))
# Out:
# Using device cuda

# %%
model_1 = MLP()
model_1.to(device=device)
# Out:
# MLP(
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
#DEFINE THE CRITERION
criterion = nn.CrossEntropyLoss()       # TO DO

# %%
#DEFINE THE OPTIMIZER
optimizer = torch.optim.SGD(model_1.parameters(),lr = 0.01)       # TO DO

# %%
n_epochs = 30

def training(n_epochs, train_loader, valid_loader, model, criterion, optimizer): # FUNCTION TO BE COMPLETED

  train_losses, valid_losses = [], []
  valid_loss_min = np.Inf

  for epoch in range(n_epochs):
      train_loss, valid_loss = 0, 0

      model.train()
      for data, label in train_loader:
          data = data.to(device=device, dtype=torch.float32)
          label = label.to(device=device, dtype=torch.long)
          optimizer.zero_grad() 
          output = model(data) 
          loss = criterion(output, label) 
          loss.backward() 
          optimizer.step() 
          train_loss += loss.item() * data.size(0)

      model.eval()
      for data, label in valid_loader:
          data = data.to(device=device, dtype=torch.float32)
          label = label.to(device=device, dtype=torch.long)
          with torch.no_grad():
              output = model(data)
          loss = criterion(output,label)
          valid_loss += loss.item() * data.size(0)

      train_loss /= len(train_loader.sampler)
      valid_loss /= len(valid_loader.sampler)
      train_losses.append(train_loss)
      valid_losses.append(valid_loss)

      print('epoch: {} \ttraining Loss: {:.6f} \tvalidation Loss: {:.6f}'.format(epoch+1, train_loss, valid_loss))

      if valid_loss <= valid_loss_min:
          print('validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
          valid_loss_min,
          valid_loss))
          torch.save(model.state_dict(), 'model.pt')
          valid_loss_min = valid_loss

  return train_losses, valid_losses

# %%
#RUN THE TRAINING FUNCTION
train_losses_1, valid_losses_1 = training(n_epochs, train_loader, valid_loader, model_1, criterion, optimizer) # TO DO
# Out:
# epoch: 1 	training Loss: 2.403794 	validation Loss: 1.060538
# validation loss decreased (inf --> 1.060538).  Saving model ...
# epoch: 2 	training Loss: 1.953589 	validation Loss: 0.880059
# validation loss decreased (1.060538 --> 0.880059).  Saving model ...
# epoch: 3 	training Loss: 1.834529 	validation Loss: 0.840260
# validation loss decreased (0.880059 --> 0.840260).  Saving model ...
# epoch: 4 	training Loss: 1.806330 	validation Loss: 0.806642
# validation loss decreased (0.840260 --> 0.806642).  Saving model ...
# epoch: 5 	training Loss: 1.761276 	validation Loss: 0.746221
# validation loss decreased (0.806642 --> 0.746221).  Saving model ...
# epoch: 6 	training Loss: 1.741701 	validation Loss: 0.751017
# epoch: 7 	training Loss: 1.718058 	validation Loss: 0.709728
# validation loss decreased (0.746221 --> 0.709728).  Saving model ...
# epoch: 8 	training Loss: 1.717599 	validation Loss: 0.646158
# validation loss decreased (0.709728 --> 0.646158).  Saving model ...
# epoch: 9 	training Loss: 1.698956 	validation Loss: 0.642359
# validation loss decreased (0.646158 --> 0.642359).  Saving model ...
# epoch: 10 	training Loss: 1.688376 	validation Loss: 0.668509
# epoch: 11 	training Loss: 1.680497 	validation Loss: 0.643433
# epoch: 12 	training Loss: 1.679217 	validation Loss: 0.628106
# validation loss decreased (0.642359 --> 0.628106).  Saving model ...
# epoch: 13 	training Loss: 1.649733 	validation Loss: 0.630515
# epoch: 14 	training Loss: 1.657584 	validation Loss: 0.627371
# validation loss decreased (0.628106 --> 0.627371).  Saving model ...
# epoch: 15 	training Loss: 1.660495 	validation Loss: 0.616565
# validation loss decreased (0.627371 --> 0.616565).  Saving model ...
# epoch: 16 	training Loss: 1.641969 	validation Loss: 0.574484
# validation loss decreased (0.616565 --> 0.574484).  Saving model ...
# epoch: 17 	training Loss: 1.620683 	validation Loss: 0.607913
# epoch: 18 	training Loss: 1.646231 	validation Loss: 0.552672
# validation loss decreased (0.574484 --> 0.552672).  Saving model ...
# epoch: 19 	training Loss: 1.612990 	validation Loss: 0.540779
# validation loss decreased (0.552672 --> 0.540779).  Saving model ...
# epoch: 20 	training Loss: 1.623044 	validation Loss: 0.598827
# epoch: 21 	training Loss: 1.607108 	validation Loss: 0.582646
# epoch: 22 	training Loss: 1.590122 	validation Loss: 0.526412
# validation loss decreased (0.540779 --> 0.526412).  Saving model ...
# epoch: 23 	training Loss: 1.593635 	validation Loss: 0.588663
# epoch: 24 	training Loss: 1.612329 	validation Loss: 0.565933
# epoch: 25 	training Loss: 1.574842 	validation Loss: 0.526884
# epoch: 26 	training Loss: 1.587262 	validation Loss: 0.541041
# epoch: 27 	training Loss: 1.584934 	validation Loss: 0.567278
# epoch: 28 	training Loss: 1.595912 	validation Loss: 0.587527
# epoch: 29 	training Loss: 1.586838 	validation Loss: 0.525806
# validation loss decreased (0.526412 --> 0.525806).  Saving model ...
# epoch: 30 	training Loss: 1.570732 	validation Loss: 0.554862

# %% [markdown]
# #### **Question 2.3** - Plot the evolution of the loss function for both training and validation sets with respect to epochs to study the convergence of the training process. <a class="anchor" id="question_2_3"></a>

# %%
# CELL TO BE COMPLETED
plt.plot(range(n_epochs), train_losses_1)
plt.plot(range(n_epochs), valid_losses_1)
plt.legend(['train', 'validation'], prop={'size': 10})
plt.title('loss function', size=10)
plt.xlabel('epoch', size=10)
plt.ylabel('loss value', size=10)
# Out:
# Text(0, 0.5, 'loss value')

# %% [markdown]
# Let us load the model corresponding to the lowest validation loss.

# %%
model_1.load_state_dict(torch.load('model.pt', map_location=device))
# Out:
# <All keys matched successfully>

# %% [markdown]
# #### **Question 2.4** - Test the best model on (unseen) test data and evaluate it’s performance in terms of overall and per-class accuracy scores. <a class="anchor" id="question_2_4"></a>

# %%
def evaluation(model, test_loader, criterion):

  test_loss = 0.0
  class_correct = list(0. for i in range(10))
  class_total = list(0. for i in range(10))

  model.eval()
  for data, label in test_loader:
      data = data.to(device=device, dtype=torch.float32)
      label = label.to(device=device, dtype=torch.long)
      with torch.no_grad():
          output = model(data)
      loss = criterion(output, label)
      test_loss += loss.item()*data.size(0)
      _, pred = torch.max(output, 1)
      correct = np.squeeze(pred.eq(label.data.view_as(pred)))
      for i in range(len(label)):
          digit = label.data[i]
          class_correct[digit] += correct[i].item()
          class_total[digit] += 1

  test_loss = test_loss/len(test_loader.sampler)
  print('test Loss: {:.6f}\n'.format(test_loss))
  for i in range(10):
      print('test accuracy of %s: %2d%% (%2d/%2d)' % (class_names[i], 100 * class_correct[i] / class_total[i], np.sum(class_correct[i]), np.sum(class_total[i])))
  print('\ntest accuracy (overall): %2.2f%% (%2d/%2d)' % (100. * np.sum(class_correct) / np.sum(class_total), np.sum(class_correct), np.sum(class_total)))

# %%
#RUN THE EVALUATION FUNCTION
evaluation(model_1, test_loader, criterion) # TO DO
# Out:
# test Loss: 0.563795
#
# test accuracy of T-shirt/top: 81% (810/1000)
# test accuracy of Trouser: 96% (969/1000)
# test accuracy of Pullover: 81% (817/1000)
# test accuracy of Dress: 89% (893/1000)
# test accuracy of Coat: 80% (809/1000)
# test accuracy of Sandal: 94% (946/1000)
# test accuracy of Shirt: 67% (675/1000)
# test accuracy of Sneaker: 94% (941/1000)
# test accuracy of Bag: 96% (966/1000)
# test accuracy of Ankle boot: 96% (961/1000)
#
# test accuracy (overall): 87.87% (8787/10000)

# %% [markdown]
# #### **Question 2.5** - Visualize some incorrect predictions by displaying test images and labels in the format: "predicted (ground-truth)". <a class="anchor" id="question_2_5"></a>

# %%
def get_all_prediction(model, loader):
    preds = torch.tensor([], dtype=torch.long)
    targets = torch.tensor([], dtype=torch.long)
    for data, label in loader:
        data = data.to(device=device, dtype=torch.float32)
        label = label.to(device=device, dtype=torch.long)
        with torch.no_grad():
            output = model(data)
        targets = torch.cat((targets, label.cpu()), dim = 0)
        preds = torch.cat((preds, torch.max(output.cpu(), 1)[1]), dim = 0)
    return targets.numpy(), preds.numpy()

# %%
#RUN THE GET_ALL_PREDICTION FUNCTION
targets, preds_1 = get_all_prediction(model_1, test_loader) # TO DO

# %%
# CELL TO BE COMPLETED
index = np.where(preds_1 - targets != 0)[0]
test_set_array = test_data.data.numpy()
plt.figure(figsize=(25, 4))
for i in range(20):
  plt.subplot(2, 10, i + 1)
  plt.axis('off')
  plt.imshow(test_set_array[index[i],:,:], cmap='gray')
  plt.title("{} ({})".format(str(class_names[int(preds_1[index[i]])]), str(class_names[int(targets[index[i]])])),color=("red"))
plt.show()

# %% [markdown]
# ## 3- Convolutional neural network (CNN) <a class="anchor" id="section_3"></a>

# %% [markdown]
# Let us now switch from MLP to convolutional neural network (CNN) to classify Fashion-MNIST images.

# %% [markdown]
# #### **Question 3.1** - Define a CNN architecture using (at least) 2 patterns [CONV - CONV - POOL] as well as dropout and fully-connected layers. <a class="anchor" id="question_3_1"></a>

# %%
class CNN(nn.Module):

    def __init__(self): # FUNCTION TO BE COMPLETED
        super(CNN,self).__init__()
        
        # Common to all layers
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.2)
        self.maxpl = nn.MaxPool2d(kernel_size=2)

        # Conv 1
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=(3,3), stride=1, padding=1) 
        # ReLU 1
        # Dropout 1
        
        # Conv 2
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(3,3), stride=1, padding=1)
        # ReLU 2
        # Dropout 2

        # MaxPool => 14x14

        # Conv 3
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3,3), stride=1, padding=1) 
        # ReLU 3
        # Dropout 3
        
        # Conv 4
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        # ReLU 4
        # Dropout 4

        # MaxPool => 7x7

        # Conv 5 =>
        self.conv5 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1) 
        # ReLU
        # Dropout
        
        # Conv 6 =>
        self.conv6 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=1, padding=1)
        # ReLU
        # Dropout

        # MaxPool => 3x3

        # Flatten
        self.flatten = nn.Flatten()

        # Dense
        self.fc = nn.Linear(3*3*1024, 10)

    def forward(self,x): # FUNCTION TO BE COMPLETED
        # Conv 1 
        out = self.conv1(x)
        out = self.relu(out)
        out = self.dropout(out)

        # Conv 2
        out = self.conv2(out)
        out = self.relu(out)
        out = self.dropout(out)

        # Max Pool 2
        out = self.maxpl(out)

        # Conv 3 
        out = self.conv3(out)
        out = self.relu(out)
        out = self.dropout(out)

        # Conv 4
        out = self.conv4(out)
        out = self.relu(out)
        out = self.dropout(out)

        # Max Pool 4
        out = self.maxpl(out)

        # Conv 5
        out = self.conv5(out)
        out = self.relu(out)
        out = self.dropout(out)

        # Conv 6
        out = self.conv6(out)
        out = self.relu(out)
        out = self.dropout(out)

        # Max Pool 6
        out = self.maxpl(out)

        # Flatten
        out = self.flatten(out)

        # Dense
        out = self.fc(out)
        
        return out

# %% [markdown]
# #### **Question 3.2** - Describe input/output sizes of each layer using summary() from torchsummary. <a class="anchor" id="question_3_2"></a>

# %%
from torchsummary import summary

model_2 = CNN()
model_2.to(device=device)

# CALL THE SUMMARY FUNCTION TO DISPLAY THE ARCHITECTURE
summary(model_2, (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 28, 28]             320
#               ReLU-2           [-1, 32, 28, 28]               0
#            Dropout-3           [-1, 32, 28, 28]               0
#             Conv2d-4           [-1, 64, 28, 28]          18,496
#               ReLU-5           [-1, 64, 28, 28]               0
#            Dropout-6           [-1, 64, 28, 28]               0
#          MaxPool2d-7           [-1, 64, 14, 14]               0
#             Conv2d-8          [-1, 128, 14, 14]          73,856
#               ReLU-9          [-1, 128, 14, 14]               0
#           Dropout-10          [-1, 128, 14, 14]               0
#            Conv2d-11          [-1, 256, 14, 14]         295,168
#              ReLU-12          [-1, 256, 14, 14]               0
#           Dropout-13          [-1, 256, 14, 14]               0
#         MaxPool2d-14            [-1, 256, 7, 7]               0
#            Conv2d-15            [-1, 512, 7, 7]       1,180,160
#              ReLU-16            [-1, 512, 7, 7]               0
#           Dropout-17            [-1, 512, 7, 7]               0
#            Conv2d-18           [-1, 1024, 7, 7]       4,719,616
#              ReLU-19           [-1, 1024, 7, 7]               0
#           Dropout-20           [-1, 1024, 7, 7]               0
#         MaxPool2d-21           [-1, 1024, 3, 3]               0
#           Flatten-22                 [-1, 9216]               0
#            Linear-23                   [-1, 10]          92,170
# ================================================================
# Total params: 6,379,786
# Trainable params: 6,379,786
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 5.50
# Params size (MB): 24.34
# Estimated Total Size (MB): 29.84
# ----------------------------------------------------------------

# %% [markdown]
# #### **Question 3.3** - Train the pre-defined CNN network with cross entropy as loss function and stochastic gradient descent as optimization algorithm. <a class="anchor" id="question_3_3"></a>

# %%
#DEFINE THE OPTIMIZER
optimizer = torch.optim.SGD(model_2.parameters(), lr=0.01)        # TO DO

# %%
#RUN THE TRAINING FUNCTION
train_losses_2, valid_losses_2 = training(n_epochs, train_loader, valid_loader, model_2, criterion, optimizer)
# Out:
# epoch: 1 	training Loss: 0.470390 	validation Loss: 0.516877
# validation loss decreased (inf --> 0.516877).  Saving model ...
# epoch: 2 	training Loss: 0.404094 	validation Loss: 0.483185
# validation loss decreased (0.516877 --> 0.483185).  Saving model ...
# epoch: 3 	training Loss: 0.370293 	validation Loss: 0.418842
# validation loss decreased (0.483185 --> 0.418842).  Saving model ...
# epoch: 4 	training Loss: 0.343961 	validation Loss: 0.409359
# validation loss decreased (0.418842 --> 0.409359).  Saving model ...
# epoch: 5 	training Loss: 0.328229 	validation Loss: 0.400896
# validation loss decreased (0.409359 --> 0.400896).  Saving model ...
# epoch: 6 	training Loss: 0.312283 	validation Loss: 0.346043
# validation loss decreased (0.400896 --> 0.346043).  Saving model ...
# epoch: 7 	training Loss: 0.298687 	validation Loss: 0.369981
# epoch: 8 	training Loss: 0.282892 	validation Loss: 0.324026
# validation loss decreased (0.346043 --> 0.324026).  Saving model ...
# epoch: 9 	training Loss: 0.272843 	validation Loss: 0.339493
# epoch: 10 	training Loss: 0.263076 	validation Loss: 0.323360
# validation loss decreased (0.324026 --> 0.323360).  Saving model ...
# epoch: 11 	training Loss: 0.252737 	validation Loss: 0.313561
# validation loss decreased (0.323360 --> 0.313561).  Saving model ...
# epoch: 12 	training Loss: 0.243457 	validation Loss: 0.289099
# validation loss decreased (0.313561 --> 0.289099).  Saving model ...
# epoch: 13 	training Loss: 0.236239 	validation Loss: 0.260636
# validation loss decreased (0.289099 --> 0.260636).  Saving model ...
# epoch: 14 	training Loss: 0.227737 	validation Loss: 0.274714
# epoch: 15 	training Loss: 0.219693 	validation Loss: 0.272669
# epoch: 16 	training Loss: 0.211515 	validation Loss: 0.269045
# epoch: 17 	training Loss: 0.203727 	validation Loss: 0.278906
# epoch: 18 	training Loss: 0.196882 	validation Loss: 0.255422
# validation loss decreased (0.260636 --> 0.255422).  Saving model ...
# epoch: 19 	training Loss: 0.189329 	validation Loss: 0.258854
# epoch: 20 	training Loss: 0.183120 	validation Loss: 0.238270
# validation loss decreased (0.255422 --> 0.238270).  Saving model ...
# epoch: 21 	training Loss: 0.177081 	validation Loss: 0.233425
# validation loss decreased (0.238270 --> 0.233425).  Saving model ...
# epoch: 22 	training Loss: 0.169014 	validation Loss: 0.244851
# epoch: 23 	training Loss: 0.165106 	validation Loss: 0.223403
# validation loss decreased (0.233425 --> 0.223403).  Saving model ...
# epoch: 24 	training Loss: 0.155999 	validation Loss: 0.226434
# epoch: 25 	training Loss: 0.148698 	validation Loss: 0.242364
# epoch: 26 	training Loss: 0.144025 	validation Loss: 0.220704
# validation loss decreased (0.223403 --> 0.220704).  Saving model ...
# epoch: 27 	training Loss: 0.137251 	validation Loss: 0.221026
# epoch: 28 	training Loss: 0.131163 	validation Loss: 0.226722
# epoch: 29 	training Loss: 0.123554 	validation Loss: 0.216858
# validation loss decreased (0.220704 --> 0.216858).  Saving model ...
# epoch: 30 	training Loss: 0.120816 	validation Loss: 0.216995

# %% [markdown]
# #### **Question 3.4** - Display in a single graph the loss functions for training and validation sets obtained with both MLP and CNN models. <a class="anchor" id="question_3_4"></a>

# %%
# CELL TO BE COMPLETED
plt.plot(range(n_epochs), train_losses_1)
plt.plot(range(n_epochs), valid_losses_1)
plt.plot(range(n_epochs), train_losses_2)mHorizontalFlip(p=0.5),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
plt.plot(range(n_epochs), valid_losses_2)
plt.legend(['MPL Train', 'MPL Val', 'CNN Train', 'CNN Val'], prop={'size': 10})
plt.title('loss function', size=10)
plt.xlabel('epoch', size=10)
plt.ylabel('loss value', size=10)
# Out:
# Text(0, 0.5, 'loss value')

# %% [markdown]
# As previously, we load the model corresponding to the lowest validation loss.

# %%
model_2.load_state_dict(torch.load('model.pt', map_location=device))
# Out:
# <All keys matched successfully>

# %% [markdown]
# #### **Question 3.5** - Test the model on test data and evaluate it through overall and per-class accuracy scores. Compare these scores with the ones obtained using MLP. <a class="anchor" id="question_3_5"></a>

# %%
#RUN THE EVALUATION FUNCTION
evaluation(model_2, test_loader, criterion) # TO DO
# Out:
# test Loss: 0.237493
#
# test accuracy of T-shirt/top: 85% (850/1000)
# test accuracy of Trouser: 98% (988/1000)
# test accuracy of Pullover: 89% (899/1000)
# test accuracy of Dress: 91% (917/1000)
# test accuracy of Coat: 85% (855/1000)
# test accuracy of Sandal: 99% (990/1000)
# test accuracy of Shirt: 73% (736/1000)
# test accuracy of Sneaker: 97% (973/1000)
# test accuracy of Bag: 99% (991/1000)
# test accuracy of Ankle boot: 95% (959/1000)
#
# test accuracy (overall): 91.58% (9158/10000)

# %% [markdown]
# #### **Question 3.6** - Display CNN results for images whose prediction was incorrect with MLP. Labels should be indicated in the following format: "MPL label (ground-truth) | CNN label" in red if wrong, green otherwise. <a class="anchor" id="question_3_6"></a>

# %%
#RUN THE GET_ALL_PREDICTION FUNCTION
targets, preds_2 = get_all_prediction(model_2, test_loader) # TO DO

# %%
# CELL TO BE COMPLETED
plt.figure(figsize=(25, 10))
for i in range(20):
  plt.subplot(4, 5, i + 1)
  plt.axis('off')
  plt.imshow(test_set_array[index[i],:,:], cmap='gray')
  plt.title("{} ({}) | {}".format(str(class_names[int(preds_1[index[i]])]), str(class_names[int(targets[index[i]])]), str(class_names[int(preds_2[index[i]])])), color=("green" if preds_2[index[i]]==targets[index[i]] else "red"))
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Question 3.7** - Display the confusion matrix for both MLP and CNN models. <a class="anchor" id="question_3_7"></a>

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, normalize=False, title='confusion matrix', cmap=plt.cm.Blues):
    # This function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("normalized confusion matrix")
    else:
        print('confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %%
# CELL TO BE COMPLETED
# compute confusion matrix
cnf_matrix_MLP = confusion_matrix(targets, preds_1)
cnf_matrix_CNN = confusion_matrix(targets, preds_2)
np.set_printoptions(precision=2)

# plot normalized confusion matrixes
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plot_confusion_matrix(cnf_matrix_MLP, classes=class_names, normalize=True, title='MLP')
plt.subplot(1, 2, 2)
plot_confusion_matrix(cnf_matrix_CNN, classes=class_names, normalize=True, title='CNN')
plt.show()
# Out:
# normalized confusion matrix
# normalized confusion matrix

# %% [markdown]
# ## 4- Transfer learning from ImageNet <a class="anchor" id="section_4"></a>

# %% [markdown]
# Transfer learning focuses on storing knowledge gained while solving one problem and applying it to a different but related problem.

# %% [markdown]
# Our goal is to use a (well-known) CNN architecture whose weights have been already trained on ImageNet to perform transfer learning and fine tuning. ImageNet is a large visual database designed for visual object recognition purposes wich contains more than 14 million images!

# %% [markdown]
# #### **Question 4.1** - Modify the Fashion-MNIST dataset to make it fit to  ImageNet by extending Fashion-MNIST images from greyscale to 3-channels images. Since the minimal image dimension as inputs of pre-trained CNN models is 48x48, you will also need to resize images. To do so, use transform.Compose(), transforms.Resize() and transforms.Grayscale(). More details on image transformations are available in the [documentation](https://pytorch.org/vision/stable/transforms.html). <a class="anchor" id="question_4_1"></a>

# %%
#CALL transforms.Compose to adapt the dataset to the VGG16 architecture
transform = transforms.Compose([
    transforms.Resize((48,48)),
    transforms.Grayscale(3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# TO DO
train_data = datasets.FashionMNIST(root = 'data', train = True, download = True, transform = transform)
test_data = datasets.FashionMNIST(root = 'data', train = False, download = True, transform = transform)

# %% [markdown]
# #### **Question 4.2** - Create training, validation and test data loaders. Check the dimensions of images arising from the modified Fasion-MNIST dataset. <a class="anchor" id="question_4_2"></a>

# %%
# CELL TO BE COMPLETED
train_loader, valid_loader, test_loader = create_data_loaders(batch_size, valid_size, train_data, test_data)   #TO DO
data_iter = data_iter = iter(train_loader) #TO DO
images, labels = next(data_iter)
print(images.numpy().shape)
# Out:
# (20, 3, 48, 48)

# %% [markdown]
# #### **Question 4.3** - Exploit a vgg16 architecture ([related paper](https://arxiv.org/pdf/1409.1556.pdf)) pre-trained on ImageNet to improve the classification scores on Fashion-MNIST through fine-tuning. See the [documentation](https://pytorch.org/vision/stable/models.html#id2) for further details. Use summary() from torchsummary to describe each of the vgg16 layers. To avoid a too long learning time, you may use only 5 epochs during fine-tuning. <a class="anchor" id="question_4_3"></a>

# %%
import torchvision.models as models

class MyVGG16(nn.Module):

    def __init__(self):
        super(MyVGG16,self).__init__()

        # Common to all layers
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.2)
        
        self.vgg16 = models.vgg16()
        
        self.fc1 = nn.Linear(1000, 100)
        # ReLU
        # Dropout
        
        self.fc2 = nn.Linear(100, 10)
        
    def forward(self,x):
        # Conv 1 
        x = self.vgg16(x)

        # Hidden
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)

        # Output
        x = self.fc2(x)

        return x

# %%
model_3 = MyVGG16()
model_3.to(device=device)
summary(model_3, (3, 48, 48))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 48, 48]           1,792
#               ReLU-2           [-1, 64, 48, 48]               0
#             Conv2d-3           [-1, 64, 48, 48]          36,928
#               ReLU-4           [-1, 64, 48, 48]               0
#          MaxPool2d-5           [-1, 64, 24, 24]               0
#             Conv2d-6          [-1, 128, 24, 24]          73,856
#               ReLU-7          [-1, 128, 24, 24]               0
#             Conv2d-8          [-1, 128, 24, 24]         147,584
#               ReLU-9          [-1, 128, 24, 24]               0
#         MaxPool2d-10          [-1, 128, 12, 12]               0
#            Conv2d-11          [-1, 256, 12, 12]         295,168
#              ReLU-12          [-1, 256, 12, 12]               0
#            Conv2d-13          [-1, 256, 12, 12]         590,080
#              ReLU-14          [-1, 256, 12, 12]               0
#            Conv2d-15          [-1, 256, 12, 12]         590,080
#              ReLU-16          [-1, 256, 12, 12]               0
#         MaxPool2d-17            [-1, 256, 6, 6]               0
#            Conv2d-18            [-1, 512, 6, 6]       1,180,160
#              ReLU-19            [-1, 512, 6, 6]               0
#            Conv2d-20            [-1, 512, 6, 6]       2,359,808
#              ReLU-21            [-1, 512, 6, 6]               0
#            Conv2d-22            [-1, 512, 6, 6]       2,359,808
#              ReLU-23            [-1, 512, 6, 6]               0
#         MaxPool2d-24            [-1, 512, 3, 3]               0
#            Conv2d-25            [-1, 512, 3, 3]       2,359,808
#              ReLU-26            [-1, 512, 3, 3]               0
#            Conv2d-27            [-1, 512, 3, 3]       2,359,808
#              ReLU-28            [-1, 512, 3, 3]               0
#            Conv2d-29            [-1, 512, 3, 3]       2,359,808
#              ReLU-30            [-1, 512, 3, 3]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                 [-1, 4096]     102,764,544
#              ReLU-34                 [-1, 4096]               0
#           Dropout-35                 [-1, 4096]               0
#            Linear-36                 [-1, 4096]      16,781,312
#              ReLU-37                 [-1, 4096]               0
#           Dropout-38                 [-1, 4096]               0
#            Linear-39                 [-1, 1000]       4,097,000
#               VGG-40                 [-1, 1000]               0
#            Linear-41                  [-1, 100]         100,100
#              ReLU-42                  [-1, 100]               0
#           Dropout-43                  [-1, 100]               0
#            Linear-44                   [-1, 10]           1,010
# ================================================================
# Total params: 138,458,654
# Trainable params: 138,458,654
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 10.42
# Params size (MB): 528.18
# Estimated Total Size (MB): 538.62
# ----------------------------------------------------------------

# %%
#DEFINE THE OPTIMIZER
optimizer = torch.optim.SGD(model_3.parameters(),lr = 0.01) # TO DO

# %%
n_epochs = 10
#RUN THE TRAINING FUNCTION
train_losses_3, valid_losses_3 = training(n_epochs, train_loader, valid_loader, model_3, criterion, optimizer) # TO DO
# Out:
# epoch: 1 	training Loss: 0.833912 	validation Loss: 0.417289
# validation loss decreased (inf --> 0.417289).  Saving model ...
# epoch: 2 	training Loss: 0.403176 	validation Loss: 0.362218
# validation loss decreased (0.417289 --> 0.362218).  Saving model ...
# epoch: 3 	training Loss: 0.328275 	validation Loss: 0.316752
# validation loss decreased (0.362218 --> 0.316752).  Saving model ...
# epoch: 4 	training Loss: 0.284802 	validation Loss: 0.291859
# validation loss decreased (0.316752 --> 0.291859).  Saving model ...
# epoch: 5 	training Loss: 0.253224 	validation Loss: 0.282468
# validation loss decreased (0.291859 --> 0.282468).  Saving model ...
# epoch: 6 	training Loss: 0.223831 	validation Loss: 0.246552
# validation loss decreased (0.282468 --> 0.246552).  Saving model ...
# epoch: 7 	training Loss: 0.203251 	validation Loss: 0.234924
# validation loss decreased (0.246552 --> 0.234924).  Saving model ...
# epoch: 8 	training Loss: 0.180236 	validation Loss: 0.274001
# epoch: 9 	training Loss: 0.162107 	validation Loss: 0.287822
# epoch: 10 	training Loss: 0.148818 	validation Loss: 0.223174
# validation loss decreased (0.234924 --> 0.223174).  Saving model ...

# %%
plt.plot(range(n_epochs), train_losses_3)
plt.plot(range(n_epochs), valid_losses_3)
plt.legend(['VGG16 Train', 'VGG16 Val'], prop={'size': 10})
plt.title('loss function', size=10)
plt.xlabel('epoch', size=10)
plt.ylabel('loss value', size=10)
# Out:
# Text(0, 0.5, 'loss value')

# %% [markdown]
# #### **Question 4.4** - Test the model on test data and evaluate it through overall and per-class accuracy scores. Compare these scores with the previously obtained ones. <a class="anchor" id="question_4_4"></a>

# %%
model_3.load_state_dict(torch.load('model.pt', map_location=device))
# Out:
# <All keys matched successfully>

# %%
#RUN THE EVALUATION FUNCTION
evaluation(model_3, test_loader, criterion) # TO DO
# Out:
# test Loss: 0.255462
#
# test accuracy of T-shirt/top: 83% (838/1000)
# test accuracy of Trouser: 98% (985/1000)
# test accuracy of Pullover: 88% (887/1000)
# test accuracy of Dress: 92% (921/1000)
# test accuracy of Coat: 89% (891/1000)
# test accuracy of Sandal: 97% (973/1000)
# test accuracy of Shirt: 73% (735/1000)
# test accuracy of Sneaker: 97% (979/1000)
# test accuracy of Bag: 98% (980/1000)
# test accuracy of Ankle boot: 96% (963/1000)
#
# test accuracy (overall): 91.52% (9152/10000)

# %% [markdown]
# #### **Question 4.5** - Display results for images whose prediction was incorrect with MLP. Labels should be indicated in the following format: "MPL label (ground-truth) | vgg16 label" in red if wrong, green otherwise. <a class="anchor" id="question_4_5"></a>

# %%
#RUN THE GET_ALL_PREDICTION FUNCTION
targets, preds_3 = get_all_prediction(model_3, test_loader) # TO DO

# %%
# CELL TO BE COMPLETED
plt.figure(figsize=(25, 10))
for i in range(20):
  plt.subplot(4, 5, i + 1)
  plt.axis('off')
  plt.imshow(test_set_array[index[i],:,:], cmap='gray')
  plt.title("{} ({}) | {}".format(str(class_names[int(preds_1[index[i]])]), str(class_names[int(targets[index[i]])]), str(class_names[int(preds_2[index[i]])])), color=("green" if preds_2[index[i]]==targets[index[i]] else "red"))
plt.tight_layout()
plt.show()

# %%
model_4 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
model_4.to(device=device)
summary(model_4, (3, 48, 48))
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /homes/f22dimar/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|████████████████████████████████████████| 528M/528M [00:49<00:00, 11.2MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 48, 48]           1,792
#               ReLU-2           [-1, 64, 48, 48]               0
#             Conv2d-3           [-1, 64, 48, 48]          36,928
#               ReLU-4           [-1, 64, 48, 48]               0
#          MaxPool2d-5           [-1, 64, 24, 24]               0
#             Conv2d-6          [-1, 128, 24, 24]          73,856
#               ReLU-7          [-1, 128, 24, 24]               0
#             Conv2d-8          [-1, 128, 24, 24]         147,584
#               ReLU-9          [-1, 128, 24, 24]               0
#         MaxPool2d-10          [-1, 128, 12, 12]               0
#            Conv2d-11          [-1, 256, 12, 12]         295,168
#              ReLU-12          [-1, 256, 12, 12]               0
#            Conv2d-13          [-1, 256, 12, 12]         590,080
#              ReLU-14          [-1, 256, 12, 12]               0
#            Conv2d-15          [-1, 256, 12, 12]         590,080
#              ReLU-16          [-1, 256, 12, 12]               0
#         MaxPool2d-17            [-1, 256, 6, 6]               0
#            Conv2d-18            [-1, 512, 6, 6]       1,180,160
#              ReLU-19            [-1, 512, 6, 6]               0
#            Conv2d-20            [-1, 512, 6, 6]       2,359,808
#              ReLU-21            [-1, 512, 6, 6]               0
#            Conv2d-22            [-1, 512, 6, 6]       2,359,808
#              ReLU-23            [-1, 512, 6, 6]               0
#         MaxPool2d-24            [-1, 512, 3, 3]               0
#            Conv2d-25            [-1, 512, 3, 3]       2,359,808
#              ReLU-26            [-1, 512, 3, 3]               0
#            Conv2d-27            [-1, 512, 3, 3]       2,359,808
#              ReLU-28            [-1, 512, 3, 3]               0
#            Conv2d-29            [-1, 512, 3, 3]       2,359,808
#              ReLU-30            [-1, 512, 3, 3]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                 [-1, 4096]     102,764,544
#              ReLU-34                 [-1, 4096]               0
#           Dropout-35                 [-1, 4096]               0
#            Linear-36                 [-1, 4096]      16,781,312
#              ReLU-37                 [-1, 4096]               0
#           Dropout-38                 [-1, 4096]               0
#            Linear-39                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 10.41
# Params size (MB): 527.79
# Estimated Total Size (MB): 538.23
# ----------------------------------------------------------------

# %%
optimizer = torch.optim.SGD(model_4.parameters(),lr = 0.01)

# %%
n_epochs = 5
#RUN THE TRAINING FUNCTION
train_losses_4, valid_losses_4 = training(n_epochs, train_loader, valid_loader, model_4, criterion, optimizer)
# Out:
# epoch: 1 	training Loss: 0.452230 	validation Loss: 0.244239
# validation loss decreased (inf --> 0.244239).  Saving model ...
# epoch: 2 	training Loss: 0.221934 	validation Loss: 0.211570
# validation loss decreased (0.244239 --> 0.211570).  Saving model ...
# epoch: 3 	training Loss: 0.171913 	validation Loss: 0.185174
# validation loss decreased (0.211570 --> 0.185174).  Saving model ...
# epoch: 4 	training Loss: 0.137880 	validation Loss: 0.181372
# validation loss decreased (0.185174 --> 0.181372).  Saving model ...
# epoch: 5 	training Loss: 0.112360 	validation Loss: 0.220707

# %%
evaluation(model_4, test_loader, criterion)
# Out:
# test Loss: 0.235142
#
# test accuracy of T-shirt/top: 79% (798/1000)
# test accuracy of Trouser: 98% (986/1000)
# test accuracy of Pullover: 82% (823/1000)
# test accuracy of Dress: 92% (929/1000)
# test accuracy of Coat: 87% (871/1000)
# test accuracy of Sandal: 98% (985/1000)
# test accuracy of Shirt: 90% (900/1000)
# test accuracy of Sneaker: 98% (985/1000)
# test accuracy of Bag: 99% (993/1000)
# test accuracy of Ankle boot: 96% (969/1000)
#
# test accuracy (overall): 92.39% (9239/10000)

# %% [markdown]
# ## 5- Challenge <a class="anchor" id="section_5"></a>

# %% [markdown]
# #### **Question 5.1** - What is your best overall test accuracy and with which methodology? The first 3 teams will obtain bonus points! <a class="anchor" id="question_5_1"></a>

# %% [markdown]
# CNN: 91.58%
